# %%
import IPython.display as display

# %%
filename = "caluculate-radius-from-lunar-eclipse.pdf"
with open(filename,"rb") as f:
    display.display_pdf(f.read(),raw=True)

# %%
fig01 = """
<iframe width="1200" height="800" src="https://www.geogebra.org/calculator/twgmnt7h" style="border: 1px solid black"></iframe>
"""
display.HTML(fig01)
# Out:
# <iframe width="1200" height="800" src="https://www.geogebra.org/calculator/twgmnt7h" style="border: 1px solid black"></iframe>

# %%
fig02 = """
<iframe width="800" height="600" src="https://www.geogebra.org/calculator/kszcrq5p" style="border: 1px solid black"></iframe>
"""
display.HTML(fig02)
# Out:
# <iframe width="800" height="600" src="https://www.geogebra.org/calculator/kszcrq5p" style="border: 1px solid black"></iframe>

# %%
fig03 = """
<iframe width="800" height="600" src="https://www.geogebra.org/calculator/wc7mckpq" style="border: 1px solid black"></iframe>
"""
display.HTML(fig03)
# Out:
# <iframe width="800" height="600" src="https://www.geogebra.org/calculator/wc7mckpq" style="border: 1px solid black"></iframe>
