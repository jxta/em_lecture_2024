# %% [markdown]
# # 最短経路にコンピュータで触れてみよう
#
# まずははじめに最短経路を紹介し，それをGraphillionを使ってどのように解くかを具体的なコードを交えて解説します．
# そのためにまずは必要なプログラムを用意します。

# %%
# !pip install graphillion
# !git clone https://github.com/nsnmsak/graphillion_tutorial
# !cp graphillion_tutorial/ja/tutorial_util.py .
# Out:
# Requirement already satisfied: graphillion in /opt/conda/lib/python3.9/site-packages (1.5)
# Requirement already satisfied: future in /opt/conda/lib/python3.9/site-packages (from graphillion) (0.18.2)
# Cloning into 'graphillion_tutorial'...
# remote: Enumerating objects: 294, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 294 (delta 3), reused 2 (delta 2), pack-reused 288
# Receiving objects: 100% (294/294), 6.61 MiB | 13.81 MiB/s, done.
# Resolving deltas: 100% (179/179), done.

# %% [markdown]
# 次にgraphillionモジュールから`GraphSet`と`tutorial`をインポートします．

# %%
from graphillion import GraphSet, tutorial
from tutorial_util import draw_subgraph, draw_universe

# %% [markdown]
# **最短経路を計算する格子を作ります**

# %%
import graphillion.tutorial as tl

# %%
universe = tl.grid(3, 3)
GraphSet.set_universe(universe)
tl.draw(universe)  # ユニバースをポップアップウィンドウで表示する

# %%
start = 1
goal = 16
paths = GraphSet.paths(start, goal)
i = 0
for path in paths:
    if len(path) == 6:
        i = i + 1
        tl.draw(path)
        print("==================================================================")
print(i)
# Out:
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# ==================================================================
# 20
